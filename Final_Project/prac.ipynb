# %%
# 보기 편하게 이름 변경
# mp4 / xml 파일들
import os

# %%
def rename_files(folder_path):
    files = os.listdir(folder_path)

    files.sort()

    video_files = [file for file in files if file.endswith('.mp4')]
    xml_files = [file for file in files if file.endswith('.xml')]
    
    def get_new_name(base_name, index, extension):
        new_name = f"{base_name}_{index}.{extension}"
        while os.path.exists(os.path.join(folder_path, new_name)):
            index += 1
            new_name = f"{base_name}_{index}.{extension}"
        return new_name

    for i, file in enumerate(video_files, start=1):
        new_name = get_new_name("damage", i, "mp4")
        os.rename(os.path.join(folder_path, file), os.path.join(folder_path, new_name))
        print(f"Renamed {file} to {new_name}")

    for i, file in enumerate(xml_files, start=1):
        new_name = get_new_name("damage", i, "xml")
        os.rename(os.path.join(folder_path, file), os.path.join(folder_path, new_name))
        print(f"Renamed {file} to {new_name}")

# 실제 폴더 경로
rename_files('C:/Users/user/Desktop/SeSaC/Final_Project/238-2.실내(편의점, 매장) 사람 이상행동 데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_03.이상행동_08.파손')
# Out:
# Renamed damage_1.mp4 to damage_81.mp4
# Renamed damage_10.mp4 to damage_82.mp4
# Renamed damage_11.mp4 to damage_10.mp4
# Renamed damage_12.mp4 to damage_11.mp4
# Renamed damage_13.mp4 to damage_12.mp4
# Renamed damage_14.mp4 to damage_13.mp4
# Renamed damage_15.mp4 to damage_14.mp4
# Renamed damage_16.mp4 to damage_15.mp4
# Renamed damage_17.mp4 to damage_16.mp4
# Renamed damage_18.mp4 to damage_17.mp4
# Renamed damage_19.mp4 to damage_18.mp4
# Renamed damage_2.mp4 to damage_19.mp4
# Renamed damage_20.mp4 to damage_83.mp4
# Renamed damage_21.mp4 to damage_20.mp4
# Renamed damage_22.mp4 to damage_21.mp4
# Renamed damage_23.mp4 to damage_22.mp4
# Renamed damage_24.mp4 to damage_23.mp4
# Renamed damage_25.mp4 to damage_24.mp4
# Renamed damage_26.mp4 to damage_25.mp4
# Renamed damage_27.mp4 to damage_26.mp4
# Renamed damage_28.mp4 to damage_27.mp4
# Renamed damage_29.mp4 to damage_28.mp4
# Renamed damage_3.mp4 to damage_29.mp4
# Renamed damage_30.mp4 to damage_84.mp4
# ...

# %%
def rename_files(folder_path):
    files = os.listdir(folder_path)

    files.sort()

    video_files = [file for file in files if file.endswith('.mp4')]
    xml_files = [file for file in files if file.endswith('.xml')]
    
    def get_new_name(base_name, index, extension):
        new_name = f"{base_name}_{index}.{extension}"
        while os.path.exists(os.path.join(folder_path, new_name)):
            index += 1
            new_name = f"{base_name}_{index}.{extension}"
        return new_name

    for i, file in enumerate(video_files, start=1):
        new_name = get_new_name("violence", i, "mp4")
        os.rename(os.path.join(folder_path, file), os.path.join(folder_path, new_name))
        print(f"Renamed {file} to {new_name}")

    for i, file in enumerate(xml_files, start=1):
        new_name = get_new_name("violence", i, "xml")
        os.rename(os.path.join(folder_path, file), os.path.join(folder_path, new_name))
        print(f"Renamed {file} to {new_name}")

# 실제 폴더 경로
rename_files('C:/Users/user/Desktop/SeSaC/Final_Project/238-2.실내(편의점, 매장) 사람 이상행동 데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_03.이상행동_13.폭행')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 27
#      24         print(f"Renamed {file} to {new_name}")
#      26 # 실제 폴더 경로
# ---> 27 rename_files('C:/Users/user/Desktop/SeSaC/Final_Project/238-2.실내(편의점, 매장) 사람 이상행동 데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_03.이상행동_13.폭행')
#
# Cell In[23], line 2, in rename_files(folder_path)
#       1 def rename_files(folder_path):
# ----> 2     files = os.listdir(folder_path)
#       4     files.sort()
#       6     video_files = [file for file in files if file.endswith('.mp4')]
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: 'C:/Users/user/Desktop/SeSaC/Final_Project/238-2.실내(편의점, 매장) 사람 이상행동 데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_03.이상행동_13.폭행'

# %%
def rename_files(folder_path):
    files = os.listdir(folder_path)

    files.sort()

    video_files = [file for file in files if file.endswith('.mp4')]
    xml_files = [file for file in files if file.endswith('.xml')]
    
    def get_new_name(base_name, index, extension):
        new_name = f"{base_name}_{index}.{extension}"
        while os.path.exists(os.path.join(folder_path, new_name)):
            index += 1
            new_name = f"{base_name}_{index}.{extension}"
        return new_name

    for i, file in enumerate(video_files, start=1):
        new_name = get_new_name("theft", i, "mp4")
        os.rename(os.path.join(folder_path, file), os.path.join(folder_path, new_name))
        print(f"Renamed {file} to {new_name}")

    for i, file in enumerate(xml_files, start=1):
        new_name = get_new_name("theft", i, "xml")
        os.rename(os.path.join(folder_path, file), os.path.join(folder_path, new_name))
        print(f"Renamed {file} to {new_name}")

# 실제 폴더 경로
rename_files('C:/Users/user/Desktop/SeSaC/Final_Project/238-2.실내(편의점, 매장) 사람 이상행동 데이터/01-1.정식개방데이터/Validation/01.원천데이터/VS_03.이상행동_12.절도')
# Out:
# Renamed theft_1.mp4 to theft_81.mp4
# Renamed theft_10.mp4 to theft_82.mp4
# Renamed theft_11.mp4 to theft_10.mp4
# Renamed theft_12.mp4 to theft_11.mp4
# Renamed theft_13.mp4 to theft_12.mp4
# Renamed theft_14.mp4 to theft_13.mp4
# Renamed theft_15.mp4 to theft_14.mp4
# Renamed theft_16.mp4 to theft_15.mp4
# Renamed theft_17.mp4 to theft_16.mp4
# Renamed theft_18.mp4 to theft_17.mp4
# Renamed theft_19.mp4 to theft_18.mp4
# Renamed theft_2.mp4 to theft_19.mp4
# Renamed theft_20.mp4 to theft_83.mp4
# Renamed theft_21.mp4 to theft_20.mp4
# Renamed theft_22.mp4 to theft_21.mp4
# Renamed theft_23.mp4 to theft_22.mp4
# Renamed theft_24.mp4 to theft_23.mp4
# Renamed theft_25.mp4 to theft_24.mp4
# Renamed theft_26.mp4 to theft_25.mp4
# Renamed theft_27.mp4 to theft_26.mp4
# Renamed theft_28.mp4 to theft_27.mp4
# Renamed theft_29.mp4 to theft_28.mp4
# Renamed theft_3.mp4 to theft_29.mp4
# Renamed theft_30.mp4 to theft_84.mp4
# Renamed theft_31.mp4 to theft_30.mp4
# ...

# %%
def rename_files(folder_path):
    files = os.listdir(folder_path)

    files.sort()

    video_files = [file for file in files if file.endswith('.mp4')]
    xml_files = [file for file in files if file.endswith('.xml')]
    
    def get_new_name(base_name, index, extension):
        new_name = f"{base_name}_{index}.{extension}"
        while os.path.exists(os.path.join(folder_path, new_name)):
            index += 1
            new_name = f"{base_name}_{index}.{extension}"
        return new_name

    for i, file in enumerate(video_files, start=1):
        new_name = get_new_name("damage", i, "mp4")
        os.rename(os.path.join(folder_path, file), os.path.join(folder_path, new_name))
        print(f"Renamed {file} to {new_name}")

    for i, file in enumerate(xml_files, start=1):
        new_name = get_new_name("damage", i, "xml")
        os.rename(os.path.join(folder_path, file), os.path.join(folder_path, new_name))
        print(f"Renamed {file} to {new_name}")

# 실제 폴더 경로
rename_files('C:/Users/user/Desktop/SeSaC/Final_Project/238-2.실내(편의점, 매장) 사람 이상행동 데이터/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_03.이상행동_08.파손')
# Out:
# Renamed C_3_8_53_BU_SMC_10-14_13-30-48_CB_RGB_DF2_F3.xml to damage_1.xml
# Renamed C_3_8_54_BU_SMC_10-14_13-32-37_CA_RGB_DF2_F3.xml to damage_2.xml
# Renamed C_3_8_54_BU_SMC_10-14_13-32-37_CC_RGB_DF2_F3.xml to damage_3.xml
# Renamed C_3_8_54_BU_SMC_10-14_13-32-37_CD_RGB_DF2_F3.xml to damage_4.xml
# Renamed C_3_8_54_BU_SMC_10-14_13-32-37_CE_RGB_DF2_F3.xml to damage_5.xml
# Renamed C_3_8_55_BU_DYB_10-17_14-19-01_CA_RGB_DF2_M3.xml to damage_6.xml
# Renamed C_3_8_55_BU_DYB_10-17_14-19-01_CB_RGB_DF2_M3.xml to damage_7.xml
# Renamed C_3_8_55_BU_DYB_10-17_14-19-01_CC_RGB_DF2_M3.xml to damage_8.xml
# Renamed C_3_8_55_BU_DYB_10-17_14-19-01_CD_RGB_DF2_M3.xml to damage_9.xml
# Renamed C_3_8_55_BU_DYB_10-17_14-19-01_CE_RGB_DF2_M3.xml to damage_10.xml
# Renamed C_3_8_55_BU_SMC_10-14_13-35-06_CA_RGB_DF2_F3.xml to damage_11.xml
# Renamed C_3_8_55_BU_SMC_10-14_13-35-06_CB_RGB_DF2_F3.xml to damage_12.xml
# Renamed C_3_8_55_BU_SMC_10-14_13-35-06_CC_RGB_DF2_F3.xml to damage_13.xml
# ...

# %%
import cv2
import ultralytics
from ultralytics import YOLO

# %%
model = YOLO("yolov8n-pose.pt")
results = model.predict('C:/Users/user/Desktop/train/video/C_3_8_53_BU_SMC_10-14_13-30-48_CB_RGB_DF2_F3.mp4',show=True,conf=0.3,save=True)
# 앞에 3초 뒤에 5초 사람없음
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/180) C:\Users\user\Desktop\train\video\C_3_8_53_BU_SMC_10-14_13-30-48_CB_RGB_DF2_F3.mp4: 384x640 (no detections), 66.7ms
# video 1/1 (2/180) C:\Users\user\Desktop\train\video\C_3_8_53_BU_SMC_10-14_13-30-48_CB_RGB_DF2_F3.mp4: 384x640 (no detections), 47.1ms
# video 1/1 (3/180) C:\Users\user\Desktop\train\video\C_3_8_53_BU_SMC_10-14_13-30-48_CB_RGB_DF2_F3.mp4: 384x640 (no detections), 69.5ms
# ...

# %%
import xml.etree.ElementTree as ET

# XML 파일을 불러와 파싱
file_path = 'C:/Users/user/Desktop/train/label/C_3_8_53_BU_SMC_10-14_13-30-48_CB_RGB_DF2_F3.xml'
tree = ET.parse(file_path)
root = tree.getroot()

# 각 'box' 태그에서 정보 추출
frame_data = {}
for box in root.iter('box'):
    frame = int(box.get('frame'))
    xtl = float(box.get('xtl'))
    ytl = float(box.get('ytl'))
    xbr = float(box.get('xbr'))
    ybr = float(box.get('ybr'))

    # 프레임별로 데이터 저장
    if frame not in frame_data:
        frame_data[frame] = []
    frame_data[frame].append((xtl, ytl, xbr, ybr))

# 추출된 데이터의 일부를 예시로 출력
example_frames = list(frame_data.keys())[:5]  # 첫 5개 프레임의 데이터를 예시로 출력
example_data = {frame: frame_data[frame] for frame in example_frames}
example_data
# Out:
# {74: [(1247.22, 162.78, 1526.39, 497.5)],
#  75: [(1247.22, 162.78, 1526.39, 497.5)],
#  146: [(976.39, 78.47, 1220.83, 692.36)],
#  147: [(976.39, 78.47, 1220.83, 692.36)]}
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다. 셀의 코드를 검토하여 오류의 가능한 원인을 식별하세요. 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'> 여기 </a> 를 클릭하세요. 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.

# %%
import xml.etree.ElementTree as ET
import os
# XML 파일 경로
file_path = 'C:/Users/user/Desktop/train/label/C_3_8_53_BU_SMC_10-14_13-30-48_CB_RGB_DF2_F3.xml'

tree = ET.parse(file_path)
root = tree.getroot()

yolo_format_data = {}

# 각 'box' 태그에서 정보 추출
for box in root.iter('box'):
    frame = int(box.get('frame'))
    xtl = float(box.get('xtl'))
    ytl = float(box.get('ytl'))
    xbr = float(box.get('xbr'))
    ybr = float(box.get('ybr'))

    img_width, img_height = 1920, 1080  # 크기 조정 필요
    x_center = ((xtl + xbr) / 2) / img_width
    y_center = ((ytl + ybr) / 2) / img_height
    width = (xbr - xtl) / img_width
    height = (ybr - ytl) / img_height


    class_index = 0  # 실제 클래스 인덱스로 수정 필요

    # 프레임별로 데이터 저장
    if frame not in yolo_format_data:
        yolo_format_data[frame] = []
    yolo_format_data[frame].append(f"{class_index} {x_center} {y_center} {width} {height}")


labels_dir = 'C:/Users/user/Desktop/SeSaC/Final_Project/labels'

if not os.path.exists(labels_dir):
    os.makedirs(labels_dir)

# 프레임별 데이터를 파일에 저장
for frame in yolo_format_data:
    file_path = os.path.join(labels_dir, f'frame_{frame}.txt')
    with open(file_path, 'w') as file:
        for item in yolo_format_data[frame]:
            file.write("%s\n" % item)

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
https://aihub.or.kr/mypage/reqst/datareqst/view.do?currMenu=157&topMenu=106&dataReqstSn=424905

# %%
import cv2
import os
# 동영상이 있는 폴더
video_path = 'C:/Users/user/Desktop/train/video/C_3_8_53_BU_SMC_10-14_13-30-48_CB_RGB_DF2_F3.mp4' 
frames_dir = 'frames'

if not os.path.exists(frames_dir):
    os.makedirs(frames_dir)     # 폴더 자동 생성

cap = cv2.VideoCapture(video_path)
frame_num = 0

while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        break

    frame_path = f'{frames_dir}/frame_{frame_num}.jpg'

    
    if frame is not None:
        cv2.imwrite(frame_path, frame)
        frame_num += 1

cap.release()

# %%
import os

frame_dir = 'frames'  # 프레임이 저장된 디렉토리
frame_paths = [os.path.join(frame_dir, f) for f in sorted(os.listdir(frame_dir)) if f.endswith('.jpg')]
train_list_path = 'train.txt'

with open(train_list_path, 'w') as file:
    for path in frame_paths:
        file.write(path + '\n')
